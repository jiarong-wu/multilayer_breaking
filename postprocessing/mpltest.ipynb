# %%
# Some attempts to figure out the plotting style. Can be ignored now.
import matplotlib as mpl
plt.style.use('./grl.mplstyle')
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "sans-serif",
#     "font.sans-serif": "Helvetica",
# })
# plt.rcParams.update({
#     "text.usetex": True,
# })
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",
    "font.sans-serif": "dejavusans",
    "mathtext.fontset": "dejavusans",
    "mathtext.fallback": "stixsans",
})
    # "mathdefault": 
    

# plt.rc('text.latex', preamble=r'\usepackage{sfmath}')
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage[cm]{sfmath}']
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'cm'

# mathtext.fontset: dejavusans
# mathtext.fallback: stixsans
# font.family:  sans serif
# font.sans-serif:  STIX sans-serif
# text.usetex:  False

# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "sans-serif",
#     "font.sans-serif": "DejaVu Sans",
#     "mathtext.fontset": "stixsans",
#     "mathtext.fallback": "stixsans",
#     "mathtext.default": "regular",
# })

# It also allows more customization to use custom defined fonts for math
# matplotlib.rcParams['mathtext.fontset'] = 'custom'
# matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
# matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
# matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

# The solution of using TeX
plt.rcParams.update({   
                    "text.usetex": True,                
                    "font.family": "sans-serif",
                    "font.sans-serif": "CMU Bright",
                    "text.latex.preamble" : r"\usepackage{cmbright}",
        })
